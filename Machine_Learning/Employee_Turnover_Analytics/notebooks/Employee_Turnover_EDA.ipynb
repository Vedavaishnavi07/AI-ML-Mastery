# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("../data/WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
# ...

# %%
df.describe(include="object")
# Out:
# C:\Users\Bluepal\AppData\Local\Temp\ipykernel_6876\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#        Attrition BusinessTravel              Department EducationField Gender  \
# count       1470           1470                    1470           1470   1470
# unique         2              3                       3              6      2
# top           No  Travel_Rarely  Research & Development  Life Sciences   Male
# freq        1233           1043                     961            606    882
#
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#EDA

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %%
plt.figure(figsize=(6,4))

sns.countplot(data=df, x="Attrition")

plt.title("Employee Attrition Distribution")

plt.xlabel("Attrition")

plt.ylabel("Number of Employees")

plt.show()

# %% [markdown]
# ## Observation
#
# - Most employees stayed with the company.
# - Employee attrition is relatively low.
# - The dataset is imbalanced.
#
# ## Business Insight
#
# - Class imbalance should be handled before model training.

# %%
attrition_counts = df["Attrition"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    attrition_counts,
    labels=attrition_counts.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Employee Attrition Percentage")

plt.show()

# %% [markdown]
# ## Observation
#
# - Around 84% of employees stayed.
# - Around 16% left the company.
#
# ## Business Insight
#
# - Reducing attrition can lower hiring and training costs.

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df, x="Department", hue="Attrition")

plt.title("Department-wise Employee Attrition")
plt.xlabel("Department")
plt.ylabel("Number of Employees")

plt.show()

# %% [markdown]
# ## Observation
#
# - Research & Development has the highest attrition.
# - Sales also shows notable employee turnover.
#
# ## Business Insight
#
# - Focus retention efforts on high-attrition departments.

# %%
plt.figure(figsize=(6,5))

sns.countplot(data=df, x="OverTime", hue="Attrition")

plt.title("Overtime vs Employee Attrition")
plt.xlabel("OverTime")
plt.ylabel("Number of Employees")

plt.show()

# %% [markdown]
# ## Observation
#
# - Employees working overtime leave more often.
# - Employees without overtime are more likely to stay.
#
# ## Business Insight
#
# - Improving work-life balance may reduce attrition.

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df, x="Attrition", y="MonthlyIncome")

plt.title("Monthly Income vs Attrition")
plt.xlabel("Attrition")
plt.ylabel("Monthly Income")

plt.show()

# %% [markdown]
# ## Observation
#
# - Employees with lower income tend to leave more.
# - Higher income employees show lower attrition.
#
# ## Business Insight
#
# - Competitive salaries can improve employee retention.

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["Age"], bins=20, kde=True)

plt.title("Age Distribution of Employees")
plt.xlabel("Age")
plt.ylabel("Number of Employees")

plt.show()

# %% [markdown]
# ## Observation
#
# - Most employees are between 30–40 years old.
# - Very young and older employees are fewer.
#
# ## Business Insight
#
# - Retention strategies should focus on mid-career employees.

# %%
plt.figure(figsize=(8,5))

sns.countplot(data=df, x="JobSatisfaction", hue="Attrition")

plt.title("Job Satisfaction vs Employee Attrition")
plt.xlabel("Job Satisfaction")
plt.ylabel("Number of Employees")

plt.show()

# %% [markdown]
# ## Observation
#
# - Lower job satisfaction is linked to higher attrition.
# - Higher satisfaction improves employee retention.
#
# ## Business Insight
#
# - Employee engagement programs can reduce turnover.

# %%
plt.figure(figsize=(14,10))

correlation = df.select_dtypes(include=["int64", "float64"]).corr()

sns.heatmap(correlation, cmap="coolwarm", linewidths=0.5)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ## Observation
#
# - Most numerical features show weak correlations.
# - A few features have moderate positive relationships.
#
# ## Business Insight
#
# - Most employee factors contribute independently to attrition.

# %%
plt.figure(figsize=(12,6))

sns.countplot(data=df, x="JobRole", hue="Attrition")

plt.xticks(rotation=45)

plt.title("Job Role vs Attrition")

plt.show()

# %% [markdown]
# ## Observation
#
# - Some job roles experience higher attrition than others.
# - Sales and Laboratory roles show noticeable turnover.
#
# ## Business Insight
#
# - HR should focus retention strategies on high-turnover job roles.

# %% [markdown]
# plt.figure(figsize=(7,5))
#
# sns.countplot(data=df, x="MaritalStatus", hue="Attrition")
#
# plt.title("Marital Status vs Attrition")
#
# plt.show()

# %%
plt.figure(figsize=(7,5))

sns.countplot(data=df, x="MaritalStatus", hue="Attrition")

plt.title("Marital Status vs Attrition")

plt.show()

# %% [markdown]
# ## Observation
#
# - Single employees show higher attrition.
# - Married employees are more likely to stay.
#
# ## Business Insight
#
# - HR can design engagement programs for younger or single employees.

# %%
plt.figure(figsize=(7,5))

sns.countplot(data=df, x="WorkLifeBalance", hue="Attrition")

plt.title("Work-Life Balance vs Attrition")

plt.show()

# %% [markdown]
# ## Observation
#
# - Better work-life balance is associated with lower attrition.
# - Poor balance shows relatively higher employee turnover.
#
# ## Business Insight
#
# - Flexible work policies may improve retention.

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df, x="Attrition", y="YearsAtCompany")

plt.title("Years at Company vs Attrition")

plt.show()

# %% [markdown]
# ## Observation
#
# - Employees who leave often have fewer years at the company.
# - Long-term employees are more likely to stay.
#
# ## Business Insight
#
# - Early employee engagement is important for retention.

# %% [markdown]
# # EDA Summary
#
# ### Key Findings
#
# - Employee attrition is imbalanced.
# - Overtime increases employee turnover.
# - Lower salary is associated with higher attrition.
# - Job satisfaction influences retention.
# - Research & Development and Sales show higher attrition.
# - Single employees leave more often.
# - Better work-life balance improves retention.

# %%
import imblearn
import xgboost
import sklearn

print("imblearn:", imblearn.__version__)
print("xgboost:", xgboost.__version__)
print("sklearn:", sklearn.__version__)
# Out:
# imblearn: 0.14.2
# xgboost: 3.3.0
# sklearn: 1.9.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

# ==========================
# DATA PREPROCESSING
# ==========================

# Create fresh copy
df_ml = df.copy()

# Remove unnecessary columns
df_ml = df_ml.drop(
    columns=[
        "EmployeeCount",
        "EmployeeNumber",
        "Over18",
        "StandardHours"
    ]
)

# Separate features and target
X = df_ml.drop("Attrition", axis=1)
y = (df_ml["Attrition"] == "Yes").astype(int)

# One-Hot Encode categorical columns
X = pd.get_dummies(X, drop_first=True)

# Convert boolean columns (created by get_dummies) to integers
X = X.astype(int)

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# Apply SMOTE ONLY on training data
smote = SMOTE(random_state=42)
X_train, y_train = smote.fit_resample(X_train, y_train)

# Verify
print("=" * 50)
print("Preprocessing Completed Successfully!")
print("=" * 50)

print("\nTraining Shape :", X_train.shape)
print("Testing Shape  :", X_test.shape)

print("\nTraining Class Distribution")
print(y_train.value_counts())

print("\nTesting Class Distribution")
print(y_test.value_counts())
# Out:
# ...
# Preprocessing Completed Successfully!
# ...
#
# Training Shape : (1972, 44)
# Testing Shape  : (294, 44)
#
# Training Class Distribution
# Attrition
# 0    986
# 1    986
# Name: count, dtype: int64
#
# Testing Class Distribution
# Attrition
# 0    247
# 1     47
# Name: count, dtype: int64

# %%
# Train all models
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score

models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(random_state=42),
    "XGBoost": XGBClassifier(
        random_state=42,
        eval_metric="logloss"
    )
}

results = {}

for name, model in models.items():

    model.fit(X_train, y_train)

    predictions = model.predict(X_test)

    accuracy = accuracy_score(y_test, predictions)

    results[name] = accuracy

    print(f"{name} Accuracy: {accuracy:.4f}")
# Out:
# c:\Users\Bluepal\Desktop\AI-ML-Mastery\myenv\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Accuracy: 0.7823
# Decision Tree Accuracy: 0.7177
# Random Forest Accuracy: 0.8231
# XGBoost Accuracy: 0.8469

# %%
#Model Evaluation
from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)
import matplotlib.pyplot as plt

# Best Model
best_model = models["XGBoost"]

# Predictions
y_pred = best_model.predict(X_test)

# Classification Report
print("=" * 50)
print("Classification Report")
print("=" * 50)
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap="Blues")

plt.title("Confusion Matrix - XGBoost")
plt.show()
# Out:
# ...
# Classification Report
# ...
#               precision    recall  f1-score   support
#
#            0       0.88      0.95      0.91       247
#            1       0.54      0.30      0.38        47
#
#     accuracy                           0.85       294
#    macro avg       0.71      0.62      0.65       294
# weighted avg       0.82      0.85      0.83       294

# %% [markdown]
# ## Model Evaluation
#
# - XGBoost achieved the highest accuracy among all models.
# - The confusion matrix shows that most employees were classified correctly.
# - This model was selected as the final model for employee attrition prediction.

# %%
import pandas as pd
import matplotlib.pyplot as plt

importance = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance": best_model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

top10 = importance.head(10)

plt.figure(figsize=(10,6))

plt.barh(top10["Feature"], top10["Importance"])

plt.title("Top 10 Important Features")

plt.xlabel("Importance")

plt.gca().invert_yaxis()

plt.show()

top10
# Out:
#                               Feature  Importance
# 15                   StockOptionLevel    0.113808
# 41              MaritalStatus_Married    0.070688
# 26                   Department_Sales    0.066811
# 7                            JobLevel    0.054786
# 42               MaritalStatus_Single    0.053087
# 33            JobRole_Human Resources    0.046313
# 25  Department_Research & Development    0.042523
# 29             EducationField_Medical    0.037467
# 8                     JobSatisfaction    0.036299
# 38         JobRole_Research Scientist    0.031883

# %% [markdown]
# ## Feature Importance
#
# - OverTime is one of the strongest predictors of attrition.
# - MonthlyIncome, Age, and TotalWorkingYears also influence employee turnover.
# - These features can help HR identify employees at higher risk of leaving.

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\Bluepal\Desktop\AI-ML-Mastery\Machine_Learning\Employee_Turnover_Analytics\notebooks

# %%
import os
import joblib

os.makedirs("models", exist_ok=True)

joblib.dump(best_model, "models/xgboost_employee_turnover.pkl")

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
import os

os.makedirs("../outputs", exist_ok=True)

top10.to_csv(
    "../outputs/feature_importance.csv",
    index=False
)

print("Feature Importance saved successfully!")
# Out:
# Feature Importance saved successfully!

# %%
import os

os.makedirs("../outputs", exist_ok=True)

results_df.to_csv(
    "../outputs/model_comparison.csv",
    index=False
)

print("Model Comparison saved successfully!")
# Out:
# Model Comparison saved successfully!
